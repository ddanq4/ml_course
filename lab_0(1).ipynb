# %% [markdown]
# # Lab work #0
# # First Name, Last Name
# # Group No

# %% [markdown]
# # 1. Using Numpy

# %% [markdown]
# **Task 1.1**: Create a NumPy array containing the numbers from 1 to 10. Perform the following operations:
# 1. Find the sum of all elements in the array.
# 2. Find the mean of all elements in the array.
# 3. Find the maximum and minimum elements in the array.
# 4. Sort the array in ascending order.

# %%
import numpy as np

a = np.arange(1, 11)
sumi = np.sum(a)
mean = np.mean(a)
maxi = np.max(a)
mini = np.min(a)
sorted_a = np.sort(a)

print(sumi)
print(mean)
print(maxi)
print(mini)
print(sorted_a)

# %% [markdown]
# **Task 1.2**: Create a 2x3 NumPy matrix containing the numbers from -10 to 10. Perform the following operations:
# 1. Find the transpose of the matrix.
# 2. Find the determinant of the matrix (It must throw an error for [non-square matrices](https://math.stackexchange.com/questions/854180/determinant-of-a-non-square-matrix)).
# 3. Multiply the matrix by a scalar (e.g., 2).
# 4. Add two matrices element-wise.

# %%
import numpy as np

a = np.linspace(-10, 10, 6).reshape(2, 3)
transpose = a.T

try:
    det = np.linalg.det(a)
except np.linalg.LinAlgError:
    det = "Error"

scalar_mult = a * 2
b = np.ones((2, 3))
sum_matrix = a + scalar_mult
print(a)
print(transpose)
print(det)
print(scalar_mult)
print(sum_matrix)
# Out:
# [[-10.  -6.  -2.]
#  [  2.   6.  10.]]
# [[-10.   2.]
#  [ -6.   6.]
#  [ -2.  10.]]
# Error
# [[-20. -12.  -4.]
#  [  4.  12.  20.]]
# [[-30. -18.  -6.]
#  [  6.  18.  30.]]

# %% [markdown]
# # 2. Using Pandas

# %% [markdown]
# **Task 2.1**: Data Loading and Inspection
#
# Load the Iris dataset into a Pandas DataFrame and inspect the first few rows.
#
# Steps:
# 1. Load the Iris dataset from a CSV file or directly from a URL.
# 2. Display the first 5 rows of the DataFrame using the head() method.
# 3. Use the info() method to get a concise summary of the DataFrame.

# %%
import pandas as pd

iris = pd.read_csv("D:/Uknord5he/BH3/ml_course/0/fisher_irises.csv")
print(iris.head())
print(iris.info())
# Out:
#    sepal_length  sepal_width  petal_length  petal width target_class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  149 non-null    float64
#  1   sepal_width   148 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal width   147 non-null    float64
#  4   target_class  149 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None

# %% [markdown]
# **Task 2.2**: Data Cleaning & Preprocessing
#
# Handle missing values and ensure data types are appropriate.
#
# Steps:
# 1. Check for any missing values in the DataFrame using isnull().sum().
# 2. If there are missing values, fill them with the mean of the respective column.
# 3. Convert any necessary columns to the appropriate data type (e.g., categorical to numerical).

# %%
import pandas as pd

iris = pd.read_csv("D:/Uknord5he/BH3/ml_course/0/fisher_irises.csv")
print(iris.isnull().sum())
iris = iris.fillna(iris.mean(numeric_only=True))
iris['target_class'] = iris['target_class'].astype('category').cat.codes
print(iris.dtypes)
# Out:
# sepal_length    1
# sepal_width     2
# petal_length    0
# petal width     3
# target_class    1
# dtype: int64
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal width     float64
# target_class       int8
# dtype: object

# %% [markdown]
# **Task 2.3**: Data Analysis
#
# Perform basic statistical analysis on the dataset.
#
# Steps:
# 1. Calculate the mean, median, and standard deviation of each numerical column.
# 2. Group the data by the 'species' column and calculate the mean of each numerical column for each species.
# 3. Use the describe() method to get a statistical summary of the DataFrame.

# %%
import pandas as pd

iris = pd.read_csv("D:/Uknord5he/BH3/ml_course/0/fisher_irises.csv")
iris = iris.fillna(iris.mean(numeric_only=True))

print(iris.mean(numeric_only=True))
print(iris.median(numeric_only=True))
print(iris.std(numeric_only=True))
print(iris.groupby("target_class").mean(numeric_only=True))
print(iris.describe())
# Out:
# sepal_length    5.829530
# sepal_width     3.055405
# petal_length    3.758667
# petal width     1.182993
# dtype: float64
# sepal_length    5.80
# sepal_width     3.00
# petal_length    4.35
# petal width     1.30
# dtype: float64
# sepal_length    0.810626
# sepal_width     0.433386
# petal_length    1.764420
# petal width     0.754972
# dtype: float64
#                  sepal_length  sepal_width  petal_length  petal width
# target_class
# Iris-setosa          5.006000     3.418000      1.464000     0.244000
# Iris-versicolor      5.936000     2.773108      4.260000     1.326000
# Iris-virginica       6.523052     2.978682      5.528571     1.978551
#        sepal_length  sepal_width  petal_length  petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.829530     3.055405      3.758667     1.182993
# std        0.810626     0.433386      1.764420     0.754972
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.700000     4.400000      6.900000     2.500000

# %% [markdown]
# **Task 2.4**: Data Visualization
#
# Visualize the distribution of data using Pandas' built-in plotting capabilities.
#
# Steps:
# 1. Create a histogram for each numerical column to visualize the distribution of data.
# 2. Create a box plot for each numerical column to identify any outliers.
# 3. Use a pair plot to visualize relationships between different numerical features.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

iris = pd.read_csv("D:/Uknord5he/BH3/ml_course/0/fisher_irises.csv")
iris = iris.fillna(iris.mean(numeric_only=True))

iris.hist()
plt.show()

iris.plot.box()
plt.show()

sns.pairplot(iris, hue="target_class")
plt.show()

# %% [markdown]
# # 3. Using Matplotlib & Seaborn

# %% [markdown]
# **Task 3.1**: Basic Plotting with Matplotlib
#
# Create basic plots to visualize the Iris dataset.
#
# Steps:
# 1. Create a scatter plot of sepal_length vs. sepal_width using Matplotlib.
# 2. Color the points by species to visualize the separation between different classes.
# 3. Add titles, labels, and a legend to the plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt

iris = pd.read_csv("D:/Uknord5he/BH3/ml_course/0/fisher_irises.csv")
iris = iris.fillna(iris.mean(numeric_only=True))

plt.scatter(iris[iris["target_class"] == "Iris-setosa"]["sepal_length"],
            iris[iris["target_class"] == "Iris-setosa"]["sepal_width"],
            color="red", label="Iris-setosa")

plt.scatter(iris[iris["target_class"] == "Iris-versicolor"]["sepal_length"],
            iris[iris["target_class"] == "Iris-versicolor"]["sepal_width"],
            color="green", label="Iris-versicolor")

plt.scatter(iris[iris["target_class"] == "Iris-virginica"]["sepal_length"],
            iris[iris["target_class"] == "Iris-virginica"]["sepal_width"],
            color="blue", label="Iris-virginica")

plt.title("Sepal Length vs Sepal Width")
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.legend()
plt.show()

# %% [markdown]
# **Task 3.2**: Advanced Visualizations with Seaborn
#
# Use Seaborn to create more complex and informative visualizations.
#
# Steps:
#
# 1. Create a pair plot using Seaborn to visualize relationships between all pairs of features in the dataset.
# 2. Use different colors to represent different species in the pair plot.
# 3. Create a violin plot to visualize the distribution of petal_length for each species.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

iris = pd.read_csv("D:/Uknord5he/BH3/ml_course/0/fisher_irises.csv")
iris = iris.fillna(iris.mean(numeric_only=True))

sns.pairplot(iris, hue="target_class")
plt.show()

sns.violinplot(x="target_class", y="petal_length", data=iris)
plt.show()

# %% [markdown]
# **Task 3.3**: Combining Matplotlib and Seaborn
#
# Combine the strengths of Matplotlib and Seaborn to create customized visualizations.
#
# Steps:
#
# 1. Create a heatmap using Seaborn to visualize the correlation matrix of the numerical features in the dataset.
# 2. Customize the heatmap by adjusting the color palette and adding annotations.
# 3. Use Matplotlib to add a title and adjust the layout of the heatmap for better readability.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

iris = pd.read_csv("D:/Uknord5he/BH3/ml_course/0/fisher_irises.csv")
iris = iris.fillna(iris.mean(numeric_only=True))

corr = iris.corr(numeric_only=True)

plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix")
plt.tight_layout()
plt.show()

# %% [markdown]
# # BONUS TASK

# %% [markdown]
# **Bonus Task** Found a code for making __interactive__ 3D plots using `Plotly`

# %% [markdown]
# https://plotly.com/python/3d-scatter-plots/

# %%
# !pip install dash
# Out:
# Collecting dash
#   Using cached dash-3.0.4-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\trima\anaconda3\lib\site-packages (from dash) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\trima\anaconda3\lib\site-packages (from dash) (3.0.3)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\trima\anaconda3\lib\site-packages (from dash) (5.24.1)
# Requirement already satisfied: importlib-metadata in c:\users\trima\anaconda3\lib\site-packages (from dash) (7.0.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\trima\anaconda3\lib\site-packages (from dash) (4.11.0)
# Requirement already satisfied: requests in c:\users\trima\anaconda3\lib\site-packages (from dash) (2.32.3)
# Collecting retrying (from dash)
#   Using cached retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: nest-asyncio in c:\users\trima\anaconda3\lib\site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\trima\anaconda3\lib\site-packages (from dash) (75.1.0)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\trima\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\trima\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\trima\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\trima\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (1.6.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\trima\anaconda3\lib\site-packages (from plotly>=5.0.0->dash) (8.2.3)
# Requirement already satisfied: packaging in c:\users\trima\anaconda3\lib\site-packages (from plotly>=5.0.0->dash) (24.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\trima\anaconda3\lib\site-packages (from Werkzeug<3.1->dash) (2.1.3)
# Requirement already satisfied: zipp>=0.5 in c:\users\trima\anaconda3\lib\site-packages (from importlib-metadata->dash) (3.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\trima\anaconda3\lib\site-packages (from requests->dash) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\trima\anaconda3\lib\site-packages (from requests->dash) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\trima\anaconda3\lib\site-packages (from requests->dash) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\trima\anaconda3\lib\site-packages (from requests->dash) (2025.4.26)
# Requirement already satisfied: six>=1.7.0 in c:\users\trima\anaconda3\lib\site-packages (from retrying->dash) (1.16.0)
# Requirement already satisfied: colorama in c:\users\trima\anaconda3\lib\site-packages (from click>=8.1.3->Flask<3.1,>=1.0.4->dash) (0.4.6)
# Using cached dash-3.0.4-py3-none-any.whl (7.9 MB)
# Using cached retrying-1.3.4-py3-none-any.whl (11 kB)
# Installing collected packages: retrying, dash
# Successfully installed dash-3.0.4 retrying-1.3.4

# %%
from dash import Dash, dcc, html, Input, Output
import plotly.express as px
import pandas as pd

df = pd.read_csv("D:/Uknord5he/BH3/ml_course/0/fisher_irises.csv")
df = df.fillna(df.mean(numeric_only=True))

app = Dash(__name__)

app.layout = html.Div([
    html.H4('Iris samples filtered by petal width'),
    dcc.Graph(id="graph"),
    html.P("Petal Width:"),
    dcc.RangeSlider(
        id='range-slider',
        min=df['petal width'].min(),
        max=df['petal width'].max(),
        step=0.1,
        marks={
            round(df['petal width'].min(), 1): str(round(df['petal width'].min(), 1)),
            round(df['petal width'].max(), 1): str(round(df['petal width'].max(), 1))
        },
        value=[0.5, 2]
    ),
])

@app.callback(
    Output("graph", "figure"),
    Input("range-slider", "value"))
def update_bar_chart(slider_range):
    low, high = slider_range
    mask = (df['petal width'] > low) & (df['petal width'] < high)

    fig = px.scatter_3d(df[mask],
        x='sepal_length',
        y='sepal_width',
        z='petal width',
        color="target_class",
        hover_data=['petal width'])
    return fig

if __name__ == '__main__':
    app.run(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
в браузері відкривається інтерактивний 3д плот
